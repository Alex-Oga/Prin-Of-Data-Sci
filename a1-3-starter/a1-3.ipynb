# %% [markdown]
# # Assignment #1.3: Making Sense of the World
#
# Data sources: [World Bank Open Data](https://data.worldbank.org)
# - [Population, total](https://data.worldbank.org/indicator/SP.POP.TOTL)
# - [Land area (sq. km)](https://data.worldbank.org/indicator/AG.LND.TOTL.K2)
#
# ### To Complete this assignment
# - On an essay question, make your answer concise.
# - On coding questions, assign the result of each task to the given variable in each cell unless stated otherwise. In other words, add the code for each task after the equal sign. Of course, you can use more variables to hold intermediate values before the final output. In addition, <span style="color:red">Use as much NumPy, pandas, PyPlot, and Seaborn as much as possible. They will make your life easier by not having to write condition and iteration statements.</span>
#
# 1. Is the data source we use for this assignment trustable? Justify.

# %% [markdown]
# *Write your answer here.*

# %% [markdown]
# 2. Import the necessary dependencies.

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# 3. Load the world population dataset by setting the **country code column** to be the row label.

# %%
df_world = pd.read_csv("./data/world_population.csv").T
df_world.columns = df_world.loc['Country Code']
df_world
# Out:
# Country Code                  ABW                          AFE  \
# Country Name                Aruba  Africa Eastern and Southern
# Country Code                  ABW                          AFE
# Indicator Name  Population, total            Population, total
# Indicator Code        SP.POP.TOTL                  SP.POP.TOTL
# 1960                      54208.0                  130836765.0
# ...                           ...                          ...
# 2017                     105361.0                  626392880.0
# 2018                     105846.0                  643090131.0
# 2019                     106310.0                  660046272.0
# 2020                     106766.0                  677243299.0
# 2021                     107195.0                  694665117.0
#
# Country Code                  AFG                         AFW  \
# Country Name          Afghanistan  Africa Western and Central
# Country Code                  AFG                         AFW
# ...

# %% [markdown]
# 4. Notice that we do not need the "Indicator Name" and	"Indicator Code". So let's removed it from `df_world`. (Save the result in the same variable.)

# %%
df_world = df_world.drop(labels=["Indicator Name", "Indicator Code"], axis = 0, inplace=False)
df_world
# Out:
# Country Code       ABW                          AFE          AFG  \
# Country Name     Aruba  Africa Eastern and Southern  Afghanistan
# Country Code       ABW                          AFE          AFG
# 1960           54208.0                  130836765.0    8996967.0
# 1961           55434.0                  134159786.0    9169406.0
# 1962           56234.0                  137614644.0    9351442.0
# ...                ...                          ...          ...
# 2017          105361.0                  626392880.0   36296111.0
# 2018          105846.0                  643090131.0   37171922.0
# 2019          106310.0                  660046272.0   38041757.0
# 2020          106766.0                  677243299.0   38928341.0
# 2021          107195.0                  694665117.0   39835428.0
#
# Country Code                         AFW         AGO        ALB      AND  \
# Country Name  Africa Western and Central      Angola    Albania  Andorra
# ...

# %% [markdown]
# 5. Load the land-area dataset by setting the **country code column** to be the row label.

# %%
df_areas = pd.read_csv("./data/land_areas.csv").T
df_areas.columns = df_areas.loc['Country Code']
df_areas
# Out:
# Country Code    ABW                          AFE          AFG  \
# Country Name  Aruba  Africa Eastern and Southern  Afghanistan
# Country Code    ABW                          AFE          AFG
# 1960            NaN                          NaN          NaN
# 1961          180.0                   14571611.0     652230.0
# 1962          180.0                   14571611.0     652230.0
# ...             ...                          ...          ...
# 2017          180.0                 14845135.053     652230.0
# 2018          180.0                 14845150.143     652230.0
# 2019          180.0                 14845162.404     652230.0
# 2020          180.0                 14845123.094     652230.0
# 2021            NaN                          NaN          NaN
#
# Country Code                         AFW        AGO      ALB      AND  \
# Country Name  Africa Western and Central     Angola  Albania  Andorra
# Country Code                         AFW        AGO      ALB      AND
# ...

# %% [markdown]
# 6. Load the region-and-income dataset by setting the first column to be the row label.

# %%
df_reg = pd.read_csv("./data/regions_and_income.csv").T
df_reg.columns = df_reg.iloc[0]
df_reg
# Out:
# Country Code                        ABW  AFE         AFG  AFW  \
# Country Code                        ABW  AFE         AFG  AFW
# Region        Latin America & Caribbean  NaN  South Asia  NaN
# IncomeGroup                 High income  NaN  Low income  NaN
#
# Country Code                  AGO                    ALB  \
# Country Code                  AGO                    ALB
# Region         Sub-Saharan Africa  Europe & Central Asia
# IncomeGroup   Lower middle income    Upper middle income
#
# Country Code                    AND  ARB                         ARE  \
# Country Code                    AND  ARB                         ARE
# Region        Europe & Central Asia  NaN  Middle East & North Africa
# IncomeGroup             High income  NaN                 High income
#
# Country Code                        ARG  ...                        VIR  \
# Country Code                        ARG  ...                        VIR
# ...

# %% [markdown]
# 7. Find the population density of each country in `df_world` by year.<br>
# *Tip*: Do dataframe calculation without non-numerical columns.

# %%
pop_density = df_world.iloc[2:, :]
pop_density
# Out:
# Country Code       ABW          AFE         AFG          AFW         AGO  \
# 1960           54208.0  130836765.0   8996967.0   96396419.0   5454938.0
# 1961           55434.0  134159786.0   9169406.0   98407221.0   5531451.0
# 1962           56234.0  137614644.0   9351442.0  100506960.0   5608499.0
# 1963           56699.0  141202036.0   9543200.0  102691339.0   5679409.0
# 1964           57029.0  144920186.0   9744772.0  104953470.0   5734995.0
# ...                ...          ...         ...          ...         ...
# 2017          105361.0  626392880.0  36296111.0  423769930.0  29816769.0
# 2018          105846.0  643090131.0  37171922.0  435229381.0  30809787.0
# 2019          106310.0  660046272.0  38041757.0  446911598.0  31825299.0
# 2020          106766.0  677243299.0  38928341.0  458803476.0  32866268.0
# 2021          107195.0  694665117.0  39835428.0  470898870.0  33933611.0
#
# Country Code        ALB      AND          ARB        ARE         ARG  ...  \
# ...

# %% [markdown]
# 8. Merge the population-density and region-and-income datasets.<br>*Tip:* Think about which column is best to merge on.

# %%
df_merged = pop_density.merge(df_reg, left_on="ABW", right_on="A")
df_merged
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [52], in <cell line: 1>()
# ----> 1 df_merged = pop_density.merge(df_reg, left_on="Country Code", right_on="Region")
#       2 df_merged
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:9345, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    9326 @Substitution("")
#    9327 @Appender(_merge_doc, indents=2)
#    9328 def merge(
#    (...)
#    9341     validate: str | None = None,
#    9342 ) -> DataFrame:
#    9343     from pandas.core.reshape.merge import merge
# -> 9345     return merge(
#    9346         self,
#    9347         right,
#    9348         how=how,
#    9349         on=on,
#    9350         left_on=left_on,
#    9351         right_on=right_on,
#    9352         left_index=left_index,
# ...

# %% [markdown]
# 9. List the number of missing values in `df_merged` by column. Put this list as a `Series` in `null_counts`.

# %%
null_counts =

# %% [markdown]
# 10. Drop columns that has no data in them (aka data in every row in that column is missing) in `df_merged`. Save the result in the same dataframe.

# %% [markdown]
# 11. Drop rows with missing data

# %%
df_clean =

# %% [markdown]
# 12. Many countries have had policies about birth rates. Some would like their citizens to have less babies during a period of time while the new trend is to encourage people to have more than one child per family. Does the number of population have something to do with the wealth of a country? Or else?<br><br>
# 12-A. Use the given datasets to create a visualization that help us investigate if the population density of a country has something to do with the level of income. Feel free to transform and select types of visualization that would best illustrate this issue. Because the time limit, I suggest that you pick only two or three columns to visualize instead of delivering a set of visualization for a whole data set.

# %% [markdown]
# 12-B. Based on your visualization, briefly discuss your observation on the issue to invetigate. If the visualization does not have any meaningful information, suggest another way of transforming data and/or an alternate type of visualization. (You do not need to create another visualization with code here.)

# %% [markdown]
# *Write your discussion here.*
