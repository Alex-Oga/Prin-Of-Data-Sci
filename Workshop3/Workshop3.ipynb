# %%
from sklearn.linear_model import LogisticRegression, LinearRegression
from scipy.special import expit

# %%
xmin = np.min(df['height'])
xmax = np.max(df['height'])
X = df['height']
y = df['male']

# %%
X = X[:, np.newaxis]
# Out:
# C:\Users\Sasha\AppData\Local\Temp\ipykernel_18620\3510263189.py:1: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   X = X[:, np.newaxis]

# %%
clf = LogisticRegression(C=1e5)
clf.fit(X, y)
# Out:
# LogisticRegression(C=100000.0)

# %%
plt.figure(1, figsize=(4, 3))
plt.clf()
plt.scatter(X.ravel(), y, color="black", zorder=20)
X_test = np.linspace(xmin, xmax, len(X))
loss = expit(X_test * clf.coef_ + clf.intercept_).ravel()
plt.plot(X_test, loss, color="red", linewidth=3)
ols = LinearRegression()
ols.fit(X, y)
plt.plot(X_test, ols.coef_ * X_test + ols.intercept_, linewidth=1)
plt.axhline(0.5, color=".5")
plt.legend(
    ("Logistic Regression Model", "Linear Regression Model"),
    loc="lower right",
    fontsize="small",
)
plt.tight_layout()
plt.show()

# %%
logr = linear_model.LogisticRegression()
logr.fit(X,y)

log_odds = logr.coef_
odds = np.exp(log_odds)
odds
# Out:
# array([[1.31139706]])

# %%
def logit2prob(logr, X):
  log_odds = logr.coef_ * X + logr.intercept_
  odds = np.exp(log_odds)
  probability = odds / (1 + odds)
  return(probability)

print(logit2prob(logr, X))
# Out:
# [[0.3773247 ]
#  [0.02249618]
#  [0.00963781]
#  [0.7060411 ]
#  [0.09776046]
#  [0.9410229 ]
#  [0.2333492 ]
#  [0.98443389]
#  [0.17744078]
#  [0.95747089]
#  [0.54677711]
#  [0.33781129]
#  [0.08359276]
#  [0.26766388]
#  [0.30043921]
#  [0.93071175]
#  [0.74046322]
#  [0.06775268]
#  [0.88906659]
#  [0.66909382]
#  [0.12397299]
#  [0.20397398]
#  [0.15369267]
#  [0.17744078]
#  [0.90494221]
#  [0.11403058]
#  [0.11403058]
#  [0.43877236]
#  [0.05161559]
#  [0.05161559]
#  [0.17744078]
#  [0.87091777]
#  [0.3773247 ]
#  [0.92471184]
#  [0.99212024]
#  [0.15369267]
#  [0.17744078]
#  [0.54677711]
#  [0.06072276]
#  [0.13307896]
#  [0.74046322]
#  [0.9639541 ]
#  [0.41853871]
#  [0.03713961]
#  [0.80316911]
#  [0.62993672]
#  [0.94988223]
#  [0.3773247 ]
#  [0.88906659]
#  [0.54677711]
#  [0.09776046]
#  [0.09776046]
#  [0.41853871]
#  [0.9410229 ]]
