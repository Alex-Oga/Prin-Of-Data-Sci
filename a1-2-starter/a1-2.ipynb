# %% [markdown]
# # Assignment #1.2: pandas

# %% [markdown]
# ## Section 1: Load and explore the dataset

# %% [markdown]
# - Adapted from https://www.packtpub.com/big-data-and-business-intelligence/data-visualisation-python by K. Bunchongchit
# - Data from https://data.worldbank.org/indicator/SP.POP.TOTL

# %% [markdown]
# Last modified by Alexander Ogay on 28/9/2022

# %% [markdown]
# In this activity, you will consolidate the skills you've acquired in the last exercise and use Pandas to do some very basic mathematical calculations on our `world_population.csv` dataset. Pandas have a consistent API, so it should be rather easy to transfer your knowledge of the mean method to median and variance.
#
# <span style="color:purple">**Commands that you need can be found at**</span>
# - https://pandas.pydata.org/docs/reference/index.html
# - https://realpython.com/python-statistics/
#
# In addition, your already existing knowledge of NumPy will come in handy.
#
# ### To Complete this assignment
# Assign the result of each task to the given variable in each cell. In other words, add the code for each task after the equal sign. Of course, you can use more variables to hold intermediate values before the final output.
#
# ####  <span style="color:red">If other modules, such as <code>statistics</code> and <code>numpy</code>, and Python's repetition in any form (while, for, comprehension) are used to complete this assignment, it will not be graded.</span>
#
# ### Loading the dataset
# 1. Import the necessary dependencies.

# %%
import pandas as pd

# %% [markdown]
# 2. Load the dataset by setting the first column to be the row label.

# %%
df = pd.read_csv('./data/world_population.csv', index_col=0)

# %% [markdown]
# 3. Look at the first two rows of the dataset <span style="color:purple; font-weight:bold">without indexing and slicing</span>.
# > pandas has its own function to do this beatifully.

# %%
df3 = df.head(2)
df3
# Out:
#                             Country Code     Indicator Name Indicator Code  \
# Country Name
# Aruba                                ABW  Population, total    SP.POP.TOTL
# Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
#
#                                     1960         1961         1962  \
# Country Name
# Aruba                            54208.0      55434.0      56234.0
# Africa Eastern and Southern  130836765.0  134159786.0  137614644.0
#
#                                     1963         1964         1965  \
# Country Name
# Aruba                            56699.0      57029.0      57357.0
# Africa Eastern and Southern  141202036.0  144920186.0  148769974.0
#
#                                     1966  ...         2012         2013  \
# Country Name                              ...
# Aruba                            57702.0  ...     102565.0     103165.0
# Africa Eastern and Southern  152752671.0  ...  547482863.0  562601578.0
#
# ...

# %% [markdown]
# 4. Generate the descriptive statistics for each column of the dataset. You need only one function (one line of code) to do this.
# > Hint: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.describe.html

# %%
df4 = df.describe()
df4
# Out:
#                1960          1961          1962          1963          1964  \
# count  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02
# mean   1.172174e+08  1.187633e+08  1.208717e+08  1.234910e+08  1.261315e+08
# std    3.695745e+08  3.739180e+08  3.804316e+08  3.889142e+08  3.974401e+08
# min    2.833000e+03  3.077000e+03  3.367000e+03  3.703000e+03  4.063000e+03
# 25%    5.022802e+05  5.109642e+05  5.206540e+05  5.311622e+05  5.421252e+05
# 50%    3.718330e+06  3.826398e+06  3.929109e+06  4.015834e+06  4.124521e+06
# 75%    2.636053e+07  2.721235e+07  2.808607e+07  2.890669e+07  2.972333e+07
# max    3.032156e+09  3.071596e+09  3.124561e+09  3.189656e+09  3.255146e+09
#
#                1965          1966          1967          1968          1969  \
# count  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02  2.640000e+02
# mean   1.288372e+08  1.316853e+08  1.345256e+08  1.374350e+08  1.404490e+08
# ...

# %% [markdown]
# ---
# ## Section 2: Indexing, Slicing, and Iterating
#
# In order to get some good and understandable insights into our dataset, we need to be able to explicitly index, slice and iterate our data to e.g. compare several countries in terms of population density growth.
#
# After looking at the distinct operations we want to display the countries Germany, Singapore, United States, and India with their population density of years 1970, 1990, 2010.
#
#
# ### Indexing
#
# Since we need several rows and columns of our dataset to complete the given task, we have to use indexing to get the right rows and columns.
# We need:
# - the row of the USA
# - the second to last row
# - the column of year 2000 as Series
# - the population density for India in 2000
#
# 5. Index the USA row as a Series <span style="color:purple; font-weight:bold">using the label</span>.

# %%
df5 = pd.Series(df.loc["United States"]).index
df5
# Out:
# Index(['Country Code', 'Indicator Name', 'Indicator Code', '1960', '1961',
#        '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970',
#        '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979',
#        '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988',
#        '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997',
#        '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006',
#        '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015',
#        '2016', '2017', '2018', '2019', '2020', '2021'],
#       dtype='object')

# %% [markdown]
# 6. Index the column of 2000 as a Series <span style="color:purple; font-weight:bold">using the label</span>.

# %%
df6 = pd.Series(df["2000"]).index
df6
# Out:
# Index(['Aruba', 'Africa Eastern and Southern', 'Afghanistan',
#        'Africa Western and Central', 'Angola', 'Albania', 'Andorra',
#        'Arab World', 'United Arab Emirates', 'Argentina',
#        ...
#        'Virgin Islands (U.S.)', 'Vietnam', 'Vanuatu', 'World', 'Samoa',
#        'Kosovo', 'Yemen, Rep.', 'South Africa', 'Zambia', 'Zimbabwe'],
#       dtype='object', name='Country Name', length=266)

# %% [markdown]
# 7. Index the population density of India in 2000 as a **Dataframe** <span style="color:purple; font-weight:bold">using labels</span>.

# %%
df7 = df.loc["India", "2000"]
df7
# Out:
# 1056575548.0

# %% [markdown]
# >**Note:**
# >Using single brackets to index columns (like with NumPy) we will get a pandas Series object.
# When using double brackets to do indexing, a DataFrame will be returned. This way we can also index several elements with one query.
# >
# >When comparing the output of the Dataframe query to the Series query, we can see the difference between Series and DataFrames
#
# 8. Index the population density of India in 2000 as a **Series** <span style="color:purple; font-weight:bold">using  labels</span>.

# %%
df8 = pd.Series(df.loc["India", "2000"]).index
df8
# Out:
# RangeIndex(start=0, stop=1, step=1)

# %% [markdown]
# ---
# ### Slicing
#
# Other than the single rows and columns and we also need to get some Subsets of the dataset.
# Here we want slices:
# - the countries in row 2 to 5
# - countries Germany, Singapore, United States, and India
# - Germany, Singapore, United States, and India with their population density of years 1970, 1990, 2010

# %% [markdown]
# 9. Slice the last two rows using a pandas function, no indexing nor slicing.

# %%
df9 = df.tail(2)
df9
# Out:
#              Country Code     Indicator Name Indicator Code       1960  \
# Country Name
# Zambia                ZMB  Population, total    SP.POP.TOTL  3070780.0
# Zimbabwe              ZWE  Population, total    SP.POP.TOTL  3776679.0
#
#                    1961       1962       1963       1964       1965  \
# Country Name
# Zambia        3164330.0  3260645.0  3360099.0  3463211.0  3570466.0
# Zimbabwe      3905038.0  4039209.0  4178726.0  4322854.0  4471178.0
#
#                    1966  ...        2012        2013        2014        2015  \
# Country Name             ...
# Zambia        3681953.0  ...  14465148.0  14926551.0  15399793.0  15879370.0
# Zimbabwe      4623340.0  ...  13115149.0  13350378.0  13586710.0  13814642.0
#
#                     2016        2017        2018        2019        2020  \
# Country Name
# Zambia        16363449.0  16853608.0  17351714.0  17861034.0  18383956.0
# Zimbabwe      14030338.0  14236599.0  14438812.0  14645473.0  14862927.0
#
# ...

# %% [markdown]
# 10. Slice countries of rows 2 to 5.

# %%
df10 = df.iloc[0:4]
df10
# Out:
#                             Country Code     Indicator Name Indicator Code  \
# Country Name
# Aruba                                ABW  Population, total    SP.POP.TOTL
# Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# Afghanistan                          AFG  Population, total    SP.POP.TOTL
# Africa Western and Central           AFW  Population, total    SP.POP.TOTL
#
#                                     1960         1961         1962  \
# Country Name
# Aruba                            54208.0      55434.0      56234.0
# Africa Eastern and Southern  130836765.0  134159786.0  137614644.0
# Afghanistan                    8996967.0    9169406.0    9351442.0
# Africa Western and Central    96396419.0   98407221.0  100506960.0
#
#                                     1963         1964         1965  \
# Country Name
# Aruba                            56699.0      57029.0      57357.0
# Africa Eastern and Southern  141202036.0  144920186.0  148769974.0
# ...

# %% [markdown]
# 11. Slice rows Germany, Singapore, United States, and India <span style="color:purple; font-weight:bold">using  labels</span>.

# %%
df11 = df.loc[['Germany', 'Singapore', 'United States', 'India']]
df11
# Out:
#               Country Code     Indicator Name Indicator Code         1960  \
# Country Name
# Germany                DEU  Population, total    SP.POP.TOTL   72814900.0
# Singapore              SGP  Population, total    SP.POP.TOTL    1646400.0
# United States          USA  Population, total    SP.POP.TOTL  180671000.0
# India                  IND  Population, total    SP.POP.TOTL  450547675.0
#
#                       1961         1962         1963         1964  \
# Country Name
# Germany         73377632.0   74025784.0   74714353.0   75318337.0
# Singapore        1702400.0    1750200.0    1795000.0    1841600.0
# United States  183691000.0  186538000.0  189242000.0  191889000.0
# India          459642166.0  469077191.0  478825602.0  488848139.0
#
#                       1965         1966  ...          2012          2013  \
# Country Name                             ...
# Germany         75963695.0   76600311.0  ...  8.042582e+07  8.064560e+07
# ...

# %% [markdown]
# 12. Slice a subset of Germany, Singapore, United States, and India for years 1970, 1990, 2010 <span style="color:purple; font-weight:bold">using  labels</span>.

# %%
df12 = df.loc[['Germany', 'Singapore', 'United States', 'India'], ['1970', '1990', '2010']]
df12
# Out:
#                       1970         1990          2010
# Country Name
# Germany         78169289.0   79433029.0  8.177693e+07
# Singapore        2074507.0    3047132.0  5.076732e+06
# United States  205052000.0  249623000.0  3.093271e+08
# India          555189797.0  873277799.0  1.234281e+09

# %% [markdown]
# ---
# ## Section 3: Use pandas to compute the Mean, Median, and Variance
# ### Mean
# Here we learn how to manipulate data in the same scenarios as we have done in NumPy. Notice both the similaity and difference.
#
# >**Note:**
# >`.iloc()` and `.loc()` are two important methods when indexing with Pandas. They allow making precise selections of data based on either the integer value index (`iloc`) or the index column (`loc`), which in our case is the country name column.

# %% [markdown]
# 13. Calculate the mean of the third row by <span style="color:purple; font-weight:bold">using `.iloc()` and/or `.loc()`</span> to access the data.

# %%
df13 = df.iloc[2, 3:].mean(axis=0)
df13
# Out:
# 19040298.20967742

# %% [markdown]
# 14. Calculate the mean of the country Germany by <span style="color:purple; font-weight:bold">using `.iloc()` and/or `.loc()`</span> to access the data.

# %%
df14 = df.loc['Germany', '1960':].mean(axis=0)
df14
# Out:
# 79666851.96774194

# %% [markdown]
# ---
# ### Median
#
# >**Notes:**
# >- When handling larger datasets, the order in which methods get executed definitely matters.
# Think about what `.head(10)` does for a moment, it simply takes your dataset and returns the first 10 rows of it, cutting down your input to the `.mean()` method drastically.
# This will definitely have an impact when using more memory intensive calculations, so keep an eye on the order.
# >- Slicing can be done in the same way as with NumPy.
# >`dataset[1:3]` will return the second and third row of our dataset.

# %% [markdown]
# 15. Calculate the median of the last row by <span style="color:purple; font-weight:bold">using `.iloc()` and/or `.loc()`</span> to access the data.

# %%
df15 = df.iloc[-1, 3:].median(axis=0)
df15
# Out:
# 10556708.5

# %% [markdown]
# 16. Calculate the medians of the first 10 countries <span style="color:purple; font-weight:bold"> (median by row)</span>.

# %%
df16 = df.iloc[0:10, 3:].median(axis=0)
df16
# Out:
# 1960     7225952.5
# 1961     7350428.5
# 1962     7479970.5
# 1963     7611304.5
# 1964     7739883.5
#            ...
# 2017    33056440.0
# 2018    33990854.5
# 2019    34933528.0
# 2020    35897304.5
# 2021    36884519.5
# Length: 62, dtype: float64

# %% [markdown]
# ---
# ### Variance

# %% [markdown]
# 17. Calculate the variances of the last 5 columns (variance by column).

# %%
df17 = df.iloc[:, -5:].var()
df17
# Out:
# 2017    9.168162e+17
# 2018    9.376984e+17
# 2019    9.582388e+17
# 2020    9.784430e+17
# 2021    9.976603e+17
# dtype: float64

# %% [markdown]
# ---
# As mentioned in the introduction of Pandas, it's interoperable with several of NumPy's features.
# Here's an example of how to use NumPy's `mean` method with a Pandas DataFrame.

# %%
# NumPy Pandas interoperability
import numpy as np

print("Pandas", df["2015"].mean())
print("NumPy", np.mean(df["2015"]))
# Out:
# Pandas 298927728.8068182
# NumPy 298927728.8068182

# %% [markdown]
# ---
# ## Section 4: Filtering, Sorting, and Reshaping
#
# Following up on the last activity, we are asked to deliver some more complex operations.
# We will, therefore, continue to work with the same dataset, our `world_population.csv`.
#
# ### Filtering
#
# To get better insights into our dataset, we want to only look at the value that fulfills certain conditions.
# Our client reaches out to us and asks us to provide lists of values that fulfills these conditions:
# - a new dataset that only contains 1970, 2000, and 2015 as columns
# - all countries that in 2000 had a greater population density than 500
# - a new dataset that only contains years 2000 and later
# - a new dataset that only contains countries that start with `A`
# - a new dataset that only contains countries that contain the word `land`

# %% [markdown]
# 18. Filter columns 1970, 2000, and 2015.

# %%
df18 = df.loc[:, ['1970', '2000', '2015']]
df18
# Out:
#                                     1970         2000         2015
# Country Name
# Aruba                            59070.0      90866.0     104339.0
# Africa Eastern and Southern  170257189.0  398113044.0  593871847.0
# Afghanistan                   11173654.0   20779957.0   34413603.0
# Africa Western and Central   120269044.0  267214544.0  401586651.0
# Angola                         5890360.0   16395477.0   27884380.0
# ...                                  ...          ...          ...
# Kosovo                         1219000.0    1700000.0    1788196.0
# Yemen, Rep.                    6193379.0   17409071.0   26497881.0
# South Africa                  22069783.0   44967713.0   55386369.0
# Zambia                         4179062.0   10415942.0   15879370.0
# Zimbabwe                       5289312.0   11881482.0   13814642.0
#
# [266 rows x 3 columns]

# %% [markdown]
# 19. Filter countries that had a greater population density than 500 in 2000.

# %%
df19 = df[df['2000'] > 500]
df19
# Out:
#                             Country Code     Indicator Name Indicator Code  \
# Country Name
# Aruba                                ABW  Population, total    SP.POP.TOTL
# Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# Afghanistan                          AFG  Population, total    SP.POP.TOTL
# Africa Western and Central           AFW  Population, total    SP.POP.TOTL
# Angola                               AGO  Population, total    SP.POP.TOTL
# ...                                  ...                ...            ...
# Kosovo                               XKX  Population, total    SP.POP.TOTL
# Yemen, Rep.                          YEM  Population, total    SP.POP.TOTL
# South Africa                         ZAF  Population, total    SP.POP.TOTL
# Zambia                               ZMB  Population, total    SP.POP.TOTL
# Zimbabwe                             ZWE  Population, total    SP.POP.TOTL
#
# ...

# %% [markdown]
# 20. Filter for years 2000 and later <span style="color:purple; font-weight:bold">without indexing and slicing</span>.

# %%
df20 = df.filter(regex="^2")
df20
# Out:
#                                     2000         2001         2002  \
# Country Name
# Aruba                            90866.0      92892.0      94992.0
# Africa Eastern and Southern  398113044.0  408522129.0  419223717.0
# Afghanistan                   20779957.0   21606992.0   22600774.0
# Africa Western and Central   267214544.0  274433894.0  281842480.0
# Angola                        16395477.0   16945753.0   17519418.0
# ...                                  ...          ...          ...
# Kosovo                         1700000.0    1701154.0    1702310.0
# Yemen, Rep.                   17409071.0   17918369.0   18443684.0
# South Africa                  44967713.0   45571272.0   46150913.0
# Zambia                        10415942.0   10692197.0   10971704.0
# Zimbabwe                      11881482.0   11923906.0   11954293.0
#
#                                     2003         2004         2005  \
# Country Name
# ...

# %% [markdown]
# 21. Filter countries that start with A.

# %%
df21 = df.filter(regex="^A", axis=0)
df21
# Out:
#                             Country Code     Indicator Name Indicator Code  \
# Country Name
# Aruba                                ABW  Population, total    SP.POP.TOTL
# Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# Afghanistan                          AFG  Population, total    SP.POP.TOTL
# Africa Western and Central           AFW  Population, total    SP.POP.TOTL
# Angola                               AGO  Population, total    SP.POP.TOTL
# Albania                              ALB  Population, total    SP.POP.TOTL
# Andorra                              AND  Population, total    SP.POP.TOTL
# Arab World                           ARB  Population, total    SP.POP.TOTL
# Argentina                            ARG  Population, total    SP.POP.TOTL
# Armenia                              ARM  Population, total    SP.POP.TOTL
# American Samoa                       ASM  Population, total    SP.POP.TOTL
# ...

# %% [markdown]
# 22. Filter countries that contain the word land.

# %%
df22 = df.filter(like='land', axis=0)
df22
# Out:
#                             Country Code     Indicator Name Indicator Code  \
# Country Name
# Switzerland                          CHE  Population, total    SP.POP.TOTL
# Channel Islands                      CHI  Population, total    SP.POP.TOTL
# Cayman Islands                       CYM  Population, total    SP.POP.TOTL
# Finland                              FIN  Population, total    SP.POP.TOTL
# Faroe Islands                        FRO  Population, total    SP.POP.TOTL
# Greenland                            GRL  Population, total    SP.POP.TOTL
# Ireland                              IRL  Population, total    SP.POP.TOTL
# Iceland                              ISL  Population, total    SP.POP.TOTL
# Marshall Islands                     MHL  Population, total    SP.POP.TOTL
# Northern Mariana Islands             MNP  Population, total    SP.POP.TOTL
# Netherlands                          NLD  Population, total    SP.POP.TOTL
# ...

# %% [markdown]
# ---
# ### Sorting
#
# They also want to get some better insights into their data so they ask you to also deliver these datasets to understand the population growth better:
# - values sorted in ascending order by 1976
# - values sorted in descending order by 2021

# %% [markdown]
# 23. Values sorted by column 1976.

# %%
df23 = df.sort_values("1976", ascending=True)
df23
# Out:
#                           Country Code     Indicator Name Indicator Code  \
# Country Name
# Tuvalu                             TUV  Population, total    SP.POP.TOTL
# Turks and Caicos Islands           TCA  Population, total    SP.POP.TOTL
# St. Martin (French part)           MAF  Population, total    SP.POP.TOTL
# Nauru                              NRU  Population, total    SP.POP.TOTL
# Sint Maarten (Dutch part)          SXM  Population, total    SP.POP.TOTL
# ...                                ...                ...            ...
# Low & middle income                LMY  Population, total    SP.POP.TOTL
# IDA & IBRD total                   IBT  Population, total    SP.POP.TOTL
# World                              WLD  Population, total    SP.POP.TOTL
# Not classified                     INX  Population, total    SP.POP.TOTL
# West Bank and Gaza                 PSE  Population, total    SP.POP.TOTL
#
#                                    1960          1961          1962  \
# ...

# %% [markdown]
# >**Note:**
# Comparisons like this are very valuable to get a good understanding not only of your dataset but also the underlying data itself.
# For example, here we can see that the ranking of the lowest densely populated countries changed.
#
# 24. Values sorted by column 2021 in descending order.

# %%
df24 = df.sort_values('2021', ascending=False)
df24
# Out:
#                     Country Code     Indicator Name Indicator Code  \
# Country Name
# World                        WLD  Population, total    SP.POP.TOTL
# IDA & IBRD total             IBT  Population, total    SP.POP.TOTL
# Low & middle income          LMY  Population, total    SP.POP.TOTL
# Middle income                MIC  Population, total    SP.POP.TOTL
# IBRD only                    IBD  Population, total    SP.POP.TOTL
# ...                          ...                ...            ...
# Palau                        PLW  Population, total    SP.POP.TOTL
# Tuvalu                       TUV  Population, total    SP.POP.TOTL
# Nauru                        NRU  Population, total    SP.POP.TOTL
# Eritrea                      ERI  Population, total    SP.POP.TOTL
# Not classified               INX  Population, total    SP.POP.TOTL
#
#                              1960          1961          1962          1963  \
# Country Name
# ...

# %% [markdown]
# ### Reshaping
#
# In order to create a visualization that focuses on 2015, they ask you to create a subset of your DataFrame which only contains one row that which holds all the values for the year 2015 mapped to the country codes as columns.
#
# #### 25. Reshape to 2015 as row and country codes as columns.

# %%
df25 = df[['2015']].T
df25
# Out:
# Country Name     Aruba  Africa Eastern and Southern  Afghanistan  \
# 2015          104339.0                  593871847.0   34413603.0
#
# Country Name  Africa Western and Central      Angola    Albania  Andorra  \
# 2015                         401586651.0  27884380.0  2880703.0  77993.0
#
# Country Name   Arab World  United Arab Emirates   Argentina  ...  \
# 2015          396028301.0             9262896.0  43131966.0  ...
#
# Country Name  Virgin Islands (U.S.)     Vietnam   Vanuatu         World  \
# 2015                       107712.0  92677082.0  271128.0  7.347679e+09
#
# Country Name     Samoa     Kosovo  Yemen, Rep.  South Africa      Zambia  \
# 2015          193510.0  1788196.0   26497881.0    55386369.0  15879370.0
#
# Country Name    Zimbabwe
# 2015          13814642.0
#
# [1 rows x 266 columns]

# %% [markdown]
# ## Section 5: Visualizing the 2015 Data

# %%
df25.sort_values(by=['2015'], axis=1, inplace=True)
ax = df25.plot.barh(stacked=True, legend=False)
ax.set_xlabel('Population')

# https://stackoverflow.com/questions/41296313/stacked-bar-chart-with-centered-labels
index = 0
for rect in ax.patches:
    # Find where everything is located
    height = rect.get_height()
    width = rect.get_width()
    x = rect.get_x()
    y = rect.get_y()
    label_x = x + width / 2
    label_y = y + height / 2

    # plot only when height is greater than specified value
    if width > 3000000000:
        ax.text(label_x, label_y, df25.columns[index], ha='center', va='center', fontsize=8)
        
    index += 1
